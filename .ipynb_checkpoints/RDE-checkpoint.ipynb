# %%
import pandas as pd
import numpy as np

# %%
rde_raw = pd.read_csv('RDE-min-2016-10-25.csv')

# %%
rde_raw.head()
# Out:
#         UniqueID  PropID  BldgID UnitID  LeaseID RS/DS  Class  Beds  Baths  \
# 0  NYPC2100201-A  NYPC21       2   01-A      3.0    RS  1BMNS     1    1.0
# 1  NYPC2100201-B  NYPC21       2   01-B      1.0    DS  2BS       2    2.0
# 2  NYPC2100201-C  NYPC21       2   01-C      5.0    AF  2B1       2    2.0
# 3  NYPC2100201-D  NYPC21       2   01-D      2.0    RS  1BMNS     1    1.0
# 4  NYPC2100201-E  NYPC21       2   01-E      7.0    RS  1BCYS     1    1.0
#
#   ustatus     ...       MarketRent24 Amenities MonthlyRentBill TotalScrieDrie  \
# 0       O     ...            3475.00      85.0         3805.00            NaN
# 1       O     ...                NaN    -126.0         2607.15            NaN
# 2       O     ...            3433.32      49.0         3366.00            NaN
# 3       O     ...            3475.00      85.0         3365.00            NaN
# 4       O     ...            3805.00      49.0         4070.28            NaN
#
# ...

# %%
rde_raw.describe()
# Out:
#              BldgID       LeaseID          Beds         Baths  SquareFootage  \
# count  11246.000000  11034.000000  11246.000000  11246.000000   11246.000000
# mean     336.350080      3.569331      1.540192      1.118175     910.927530
# std      221.612373      2.755308      0.613566      0.323655     164.251318
# min        1.000000      1.000000      0.000000      1.000000     393.000000
# 25%       20.000000      1.000000      1.000000      1.000000     764.000000
# 50%      400.000000      2.000000      1.000000      1.000000     932.000000
# 75%      522.000000      5.000000      2.000000      1.000000     952.000000
# max      655.000000     15.000000      5.000000      3.000000    2176.000000
#
#        RobertsPriorLegalRent  RobertsCurrentLegalRent  RobertsCurrentPrefRent  \
# count            1096.000000              1094.000000              665.000000
# mean             4204.493668              4260.202605             4137.112421
# ...

# %%
for c in rde_raw.columns:
    print c
# Out:
# PropID
# BldgID
# UnitID
# LeaseID
# Building
# Class
# nclassid
# Beds
# Baths
# UnitStatus
# YieldStarClass
# RobertsUnit
# RobertsUnitClass
# SquareFootage
# Finish
# ConcessionType
# LeaseType
# LastRenovatedDate
# OccupiedVacant
# Resident
# Resident2
# Resident3
# Resident4
# Resident5
# OccupancyDate
# Term
# LeaseStart
# LeaseEnd
# EarlyTerminationDate
# RenewalLeaseStart
# RenewalLeaseEnd
# RenewalTerm
# RobertsPriorLegalRent
# RobertsBasicIncrease
# RobertsCurrentLegalRent
# RobertsCurrentPrefRent
# RobertsPrefIncrease
# RobertsNewPrefRent
# LegalRent
# SecurityDeposit
# MarketRent
# MarketRent12
# MarketRent24
# MarketRentWithAmenities
# AmenityTotal
# MonthlyRentBill
# NetAmortizedConcessions
# SCRIEDRIERent
# Refrigerator
# Stove
# ElectricalRenovation
# MCIElectric
# MCIWindowReplacement
# MCIElevator
# MCIOptOutElectric
# MCIRoofReplacement
# MCIIntercom
# MCIFuture1
# MCISecurity
# MCIWater
# MCIFuture5
# MCIFuture6
# MCIFuture7
# MCIFuture8
# MCIFuture9
# ...

# %%
rde_raw.corr()
# Out:
#                             BldgID   LeaseID      Beds     Baths  \
# BldgID                    1.000000  0.030479 -0.050848 -0.045534
# LeaseID                   0.030479  1.000000 -0.166119 -0.131871
# Beds                     -0.050848 -0.166119  1.000000  0.343958
# Baths                    -0.045534 -0.131871  0.343958  1.000000
# SquareFootage            -0.077769 -0.180664  0.790340  0.725974
# RobertsPriorLegalRent    -0.012315  0.505228  0.338187  0.364043
# RobertsCurrentLegalRent  -0.010086  0.507052  0.333487  0.364810
# RobertsCurrentPrefRent   -0.075811 -0.150854  0.696145  0.602920
# RobertsNewPrefRent       -0.080662 -0.160424  0.679190  0.607327
# LegalRent                -0.002657  0.787139  0.059013  0.066378
# MarketRent12             -0.071036 -0.114355  0.835665  0.692522
# MarketRent24             -0.071207 -0.114666  0.836502  0.694479
# Amenities                -0.027849  0.381216 -0.052639 -0.276034
# ...

# %%
rde_raw[rde_raw['Missing Rent'].is_null()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-af7b3ab891d9> in <module>()
# ----> 1 rde_raw[rde_raw['Missing Rent'].is_null()]
#
# C:\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'is_null'

# %%
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 11216    True
# 11217    True
# 11218    True
# 11219    True
# 11220    True
# 11221    True
# 11222    True
# 11223    True
# 11224    True
# 11225    True
# 11226    True
# 11227    True
# 11228    True
# 11229    True
# 11230    True
# 11231    True
# 11232    True
# 11233    True
# 11234    True
# 11235    True
# 11236    True
# 11237    True
# 11238    True
# 11239    True
# 11240    True
# 11241    True
# 11242    True
# 11243    True
# 11244    True
# 11245    True
# ...
