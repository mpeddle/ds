# %%
# %run ../ThinkStats2/code/nsfg.py
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in <module>()
#     104
#     105 if __name__ == '__main__':
# --> 106     main(*sys.argv)
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in main(script)
#      80     script: string script name
#      81     """
# ---> 82     df = ReadFemPreg()
#      83     print(df.shape)
#      84
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in ReadFemPreg(dct_file, dat_file)
#      24     returns: DataFrame
#      25     """
# ---> 26     dct = thinkstats2.ReadStataDct(dct_file)
#      27     df = dct.ReadFixedWidth(dat_file, compression='gzip')
#      28     CleanFemPreg(df)
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\thinkstats2.py in ReadStataDct(dct_file, **options)
#    2644
#    2645     var_info = []
# ...

# %%
cd ../ThinkStats2/
# Out:
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2

# %%
# %run code/nsfg.py
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in <module>()
#     104
#     105 if __name__ == '__main__':
# --> 106     main(*sys.argv)
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in main(script)
#      80     script: string script name
#      81     """
# ---> 82     df = ReadFemPreg()
#      83     print(df.shape)
#      84
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\nsfg.py in ReadFemPreg(dct_file, dat_file)
#      24     returns: DataFrame
#      25     """
# ---> 26     dct = thinkstats2.ReadStataDct(dct_file)
#      27     df = dct.ReadFixedWidth(dat_file, compression='gzip')
#      28     CleanFemPreg(df)
#
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code\thinkstats2.py in ReadStataDct(dct_file, **options)
#    2644
#    2645     var_info = []
# ...

# %%
cd code
# Out:
# C:\Users\mpeddle\PyCharmProjects\ThinkStats2\code

# %%
# %run nsfg.py
# Out:
# (13593, 244)
# nsfg.py: All tests passed.

# %%
import nsfg

# %%
df = nsfg.ReadFemPreg()
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %%
df.columns
# Out:
# Index([         u'caseid',        u'pregordr',       u'howpreg_n',
#              u'howpreg_p',        u'moscurrp',        u'nowprgdk',
#               u'pregend1',        u'pregend2',        u'nbrnaliv',
#               u'multbrth',
#        ...
#             u'laborfor_i',      u'religion_i',         u'metro_i',
#                u'basewgt', u'adj_mod_basewgt',        u'finalwgt',
#                 u'secu_p',            u'sest',         u'cmintvw',
#            u'totalwgt_lb'],
#       dtype='object', length=244)

# %%
df.columns[1]
# Out:
# u'pregordr'

# %%
pregordr = df['pregordr']

# %%
type(pregordr)
# Out:
# pandas.core.series.Series

# %%
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
# 5        1
# 6        2
# 7        3
# 8        1
# 9        2
# 10       1
# 11       1
# 12       2
# 13       3
# 14       1
# 15       2
# 16       3
# 17       1
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       3
# 26       1
# 27       1
# 28       2
# 29       3
#         ..
# 13563    2
# 13564    3
# 13565    1
# 13566    1
# 13567    1
# 13568    2
# 13569    1
# 13570    2
# 13571    3
# 13572    4
# 13573    1
# 13574    2
# 13575    1
# 13576    1
# 13577    2
# 13578    1
# 13579    2
# 13580    1
# 13581    2
# 13582    3
# 13583    1
# 13584    2
# 13585    1
# 13586    2
# 13587    3
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, dtype: int64

# %%
from nsfg import CleanFemPreg

# %%
CleanFemPreg(df)

# %%
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %%
df.outcome.value_counts(sort=False)
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %%
df.birthwgt_lb.value_counts(sort=False)
# Out:
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: birthwgt_lb, dtype: int64
